# %% [markdown]
# <a href="https://colab.research.google.com/github/jason272727/Python-API-Practice/blob/main/%E3%80%8C%E5%8F%A3%E7%BD%A9%E8%B3%87%E6%96%99API%E4%B8%B2%E6%8E%A5_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests  
import json
import pandas as pd
RawData = requests.get('https://raw.githubusercontent.com/kiang/pharmacies/master/json/points.json')
responseData = RawData.text
JsonData = json.loads(responseData)
df = pd.json_normalize(JsonData, record_path='features')
df
# Out:
#          type properties.id   properties.name properties.phone  \
# 0     Feature    5901010076              榮星藥局     (02)27124696
# 1     Feature    5901010085              安世藥局     (02)27133405
# 2     Feature    5901010094              明一藥局     (02)27691654
# 3     Feature    5901010165              傑安藥局     (02)27524155
# 4     Feature    5901010174              仁弘藥局     (02)27136764
# ...       ...           ...               ...              ...
# 3288  Feature    5903271111            西屯長安藥局     (04)22981221
# 3289  Feature    0291010010            連江縣立醫院      (083)623995
# 3290  Feature    5934031254          佑全蘇澳中山藥局      (03)9961063
# 3291  Feature    5937031765           和美啄木鳥藥局      (04)7552924
# 3292  Feature    0145080011  衛生福利部花蓮醫院豐濱原住民分院      (03)8358141
#
#            properties.address  properties.mask_adult  properties.mask_child  \
# 0        臺北市松山區南京東路４段１３３巷５弄１號                      0                   2490
# ...
